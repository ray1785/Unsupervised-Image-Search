# %% [markdown]
# # Unsupervised Image Retrieval
#
# This toy project is about using unsupervised deep learning model  (Autoencoder)
# with K-nearest neighbors or Locality Sensistive Hashing to find the most similar images

# %%
# import general libraries
import numpy as np
import pickle
import os
from tqdm import tqdm
from multiprocess import Pool
import random

# import libraries for plotting figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# import image processing libraries
import cv2

# import sklearn libraries
from sklearn.model_selection import train_test_split

# import tensorflow and keras
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, UpSampling2D, Add, Input
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing import image
import tensorflow.keras.backend as K

from tensorflow.keras.datasets import fashion_mnist

# google colab for save model
from google.colab import drive

# KNN
from sklearn.neighbors import NearestNeighbors

# %%
drive.mount('/content/MyDrive')
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %%
# define some constants
MODEL_LOC='/content/MyDrive/MyDrive/Colab Notebooks/Unsupervised Image Search/models/model.h5'

# %% [markdown]
# ## 2 Prepare Data
#
#
# 1.   download the dataset
# 2.   check its shape
# 3.   normalize the data
# 4.   add  channel
# 5.   visualize sample images

# %%
# We are not going to use Y for this project
(X_train, _), (X_test, _) = fashion_mnist.load_data()
print('Training set size:', X_train.shape)
print('Test set size:', X_test.shape)
# Out:
# Training set size: (60000, 28, 28)
# Test set size: (10000, 28, 28)

# %%
# normalize the data
X_train_normalized = X_train.astype('float32') / 255.0
X_test_normalized= X_test.astype('float32') / 255.0

# %%
# add channel 
X_train = np.expand_dims(X_train, axis=-1)
X_train_normalized = np.expand_dims(X_train_normalized, axis=-1)

X_test = np.expand_dims(X_test, axis=-1)
X_test_normalized = np.expand_dims(X_test_normalized, axis=-1)

print('Training set size:', X_train.shape)
print('Test set size:', X_test.shape)
print('Training set size  (normalized):', X_train_normalized.shape)
print('Test set size (normalized)', X_test_normalized.shape)
# Out:
# Training set size: (60000, 28, 28, 1)
# Test set size: (10000, 28, 28, 1)
# Training set size  (normalized): (60000, 28, 28, 1)
# Test set size (normalized) (10000, 28, 28, 1)

# %%
# visualize the data
n_rows = n_cols = 4
fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 10))

axes =  axes.ravel()
for i in range(n_rows * n_cols):
  rnd = np.random.randint(len(X_train))
  axe = axes[i]
  axe.imshow(X_train[rnd].squeeze(),  cmap=plt.cm.copper)
  axe.axis('off')

# %% [markdown]
# ## 2 Build the Model

# %%
# input
input_img = Input(shape=(28, 28, 1))

# encoder
x1 = Conv2D(64, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(input_img)
x2 = Conv2D(64, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(x1)
x3 = MaxPool2D(pool_size=(2,2), padding='same')(x2)

x4 = Conv2D(128, (3, 3), activation='elu', padding='same', kernel_regularizer=regularizers.l1(10e-10) )(x3)
x5 = Conv2D(128, (3, 3), activation='elu', padding='same', kernel_regularizer=regularizers.l1(10e-10) )(x4)
x6 = MaxPool2D( pool_size=(2,2), padding='same')(x5)

encoded = Conv2D(256, (3, 3), activation='elu', padding='same', kernel_regularizer=regularizers.l1(10e-10), name='encoder')(x6)

# decoder
x7 = UpSampling2D()(encoded)
x8 = Conv2D(128, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(x7)
x9 = Conv2D(128, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(x8)
x10 = Add()([x5, x9])

x11 = UpSampling2D()(x10)
x12 = Conv2D(64, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(x11)
x13 = Conv2D(64, (3, 3), padding='same', activation='elu', kernel_regularizer=regularizers.l2(0.01))(x12)
x14 = Add()([x2, x13])

decoded =  Conv2D(1, (3, 3), padding='same', activation='sigmoid', kernel_regularizer=regularizers.l2(0.01), name='decoder')(x14)

autoencoder = Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 64)   640         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 64)   36928       conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 64)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 128)  147584      conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 128)    0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# encoder (Conv2D)                (None, 7, 7, 256)    295168      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 14, 14, 256)  0           encoder[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 128)  295040      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 128)  147584      conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 128)  0           conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 28, 28, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 64)   73792       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 64)   0           conv2d_19[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# decoder (Conv2D)                (None, 28, 28, 1)    577         add_5[0][0]
# ==================================================================================================
# Total params: 1,108,097
# Trainable params: 1,108,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model( autoencoder, show_shapes=True, show_layer_names=True)

# %%
optimizer = keras.optimizers.Adam(beta_1=0.9, beta_2=0.999, epsilon=1e-07)
autoencoder.compile(optimizer=optimizer, loss='mse', metrics=['accuracy'])

# %%
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
model_checkpoint =  ModelCheckpoint(MODEL_LOC, save_best_only = True)

# %%
def scheduler(epoch):
    lr = 0.
    if epoch < 20 : 
        lr = 0.001
    else:
        #lr = 0.001 * np.exp(0.1 * (10 - epoch))
        lr =  0.001 * np.exp(0.0070 * (10 - (epoch -20)))
    print("current running rate:", lr )
    return lr

lrscheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
history = autoencoder.fit(X_train_normalized,X_train_normalized,
            batch_size=64,
            epochs=200,
            validation_data=(X_test_normalized, X_test_normalized),
            callbacks=[early_stopper, model_checkpoint, lrscheduler])
# Out:
# Epoch 1/200
# current running rate: 0.001
# 938/938 [==============================] - 60s 63ms/step - loss: 0.4828 - accuracy: 0.5064 - val_loss: 0.0157 - val_accuracy: 0.5072
# Epoch 2/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0174 - accuracy: 0.5099 - val_loss: 0.0139 - val_accuracy: 0.5073
# Epoch 3/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0149 - accuracy: 0.5097 - val_loss: 0.0129 - val_accuracy: 0.5074
# Epoch 4/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0125 - accuracy: 0.5105 - val_loss: 0.0129 - val_accuracy: 0.5075
# Epoch 5/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0121 - accuracy: 0.5100 - val_loss: 0.0113 - val_accuracy: 0.5075
# Epoch 6/200
# current running rate: 0.001
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2208 - accuracy: 0.3837 - val_loss: 0.6473 - val_accuracy: 0.0080
# Epoch 7/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.1694 - accuracy: 0.4644 - val_loss: 0.0125 - val_accuracy: 0.5075
# Epoch 8/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0121 - accuracy: 0.5090 - val_loss: 0.0115 - val_accuracy: 0.5076
# Epoch 9/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0129 - accuracy: 0.5094 - val_loss: 0.0108 - val_accuracy: 0.5076
# Epoch 10/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0125 - accuracy: 0.5107 - val_loss: 0.0101 - val_accuracy: 0.5076
# Epoch 11/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0110 - accuracy: 0.5093 - val_loss: 0.0101 - val_accuracy: 0.5076
# Epoch 12/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0098 - accuracy: 0.5103 - val_loss: 0.0096 - val_accuracy: 0.5076
# Epoch 13/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0095 - accuracy: 0.5106 - val_loss: 0.0093 - val_accuracy: 0.5076
# Epoch 14/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0114 - accuracy: 0.5102 - val_loss: 0.0092 - val_accuracy: 0.5077
# Epoch 15/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0090 - accuracy: 0.5091 - val_loss: 0.0086 - val_accuracy: 0.5077
# Epoch 16/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0127 - accuracy: 0.5098 - val_loss: 0.0084 - val_accuracy: 0.5077
# Epoch 17/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0084 - accuracy: 0.5097 - val_loss: 0.0089 - val_accuracy: 0.5076
# Epoch 18/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0092 - accuracy: 0.5094 - val_loss: 0.0080 - val_accuracy: 0.5077
# Epoch 19/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0086 - accuracy: 0.5102 - val_loss: 0.3162 - val_accuracy: 0.4999
# Epoch 20/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2352 - accuracy: 0.5015 - val_loss: 0.0185 - val_accuracy: 0.5074
# Epoch 21/200
# current running rate: 0.0010725081812542165
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0118 - accuracy: 0.5095 - val_loss: 0.0085 - val_accuracy: 0.5077
# Epoch 22/200
# current running rate: 0.0010650268392313055
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0084 - accuracy: 0.5099 - val_loss: 0.0079 - val_accuracy: 0.5077
# Epoch 23/200
# current running rate: 0.0010575976837366113
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0080 - accuracy: 0.5104 - val_loss: 0.0086 - val_accuracy: 0.5077
# Epoch 24/200
# current running rate: 0.001050220350740028
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0078 - accuracy: 0.5091 - val_loss: 0.0075 - val_accuracy: 0.5077
# Epoch 25/200
# current running rate: 0.0010428944787507634
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0076 - accuracy: 0.5101 - val_loss: 0.0074 - val_accuracy: 0.5077
# Epoch 26/200
# current running rate: 0.0010356197087996234
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0789 - accuracy: 0.4752 - val_loss: 0.1052 - val_accuracy: 0.5062
# Epoch 27/200
# current running rate: 0.001028395684421425
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0744 - accuracy: 0.5068 - val_loss: 0.0111 - val_accuracy: 0.5077
# Epoch 28/200
# current running rate: 0.0010212220516375285
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0103 - accuracy: 0.5098 - val_loss: 0.0089 - val_accuracy: 0.5077
# Epoch 29/200
# current running rate: 0.0010140984589384922
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0085 - accuracy: 0.5104 - val_loss: 0.0079 - val_accuracy: 0.5077
# Epoch 30/200
# current running rate: 0.0010070245572668486
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0078 - accuracy: 0.5102 - val_loss: 0.0076 - val_accuracy: 0.5077
# Epoch 31/200
# current running rate: 0.001
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0075 - accuracy: 0.5095 - val_loss: 0.0073 - val_accuracy: 0.5077
# Epoch 32/200
# current running rate: 0.0009930244429332351
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0074 - accuracy: 0.5094 - val_loss: 0.0073 - val_accuracy: 0.5077
# Epoch 33/200
# current running rate: 0.000986097544262862
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0072 - accuracy: 0.5093 - val_loss: 0.0071 - val_accuracy: 0.5077
# Epoch 34/200
# current running rate: 0.0009792189645694595
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0122 - accuracy: 0.5110 - val_loss: 0.0071 - val_accuracy: 0.5077
# Epoch 35/200
# current running rate: 0.0009723883668012468
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0070 - accuracy: 0.5091 - val_loss: 0.0069 - val_accuracy: 0.5078
# Epoch 36/200
# current running rate: 0.0009656054162575665
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0069 - accuracy: 0.5102 - val_loss: 0.0068 - val_accuracy: 0.5078
# Epoch 37/200
# current running rate: 0.0009588697805724846
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0068 - accuracy: 0.5096 - val_loss: 0.0067 - val_accuracy: 0.5078
# Epoch 38/200
# current running rate: 0.0009521811296985049
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0736 - accuracy: 0.5056 - val_loss: 0.0468 - val_accuracy: 0.5077
# Epoch 39/200
# current running rate: 0.0009455391358903963
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0302 - accuracy: 0.5113 - val_loss: 0.0138 - val_accuracy: 0.5078
# Epoch 40/200
# current running rate: 0.0009389434736891332
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0121 - accuracy: 0.5099 - val_loss: 0.0090 - val_accuracy: 0.5078
# Epoch 41/200
# current running rate: 0.0009323938199059483
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0092 - accuracy: 0.5093 - val_loss: 0.0072 - val_accuracy: 0.5078
# Epoch 42/200
# current running rate: 0.0009258898536064953
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0071 - accuracy: 0.5109 - val_loss: 0.0070 - val_accuracy: 0.5078
# Epoch 43/200
# current running rate: 0.0009194312560951247
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0066 - accuracy: 0.5102 - val_loss: 0.0064 - val_accuracy: 0.5078
# Epoch 44/200
# current running rate: 0.0009130177108992658
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0065 - accuracy: 0.5093 - val_loss: 0.0063 - val_accuracy: 0.5078
# Epoch 45/200
# current running rate: 0.0009066489037539209
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0076 - accuracy: 0.5091 - val_loss: 0.2720 - val_accuracy: 0.4999
# Epoch 46/200
# current running rate: 0.0009003245225862656
# 938/938 [==============================] - 57s 61ms/step - loss: 0.1491 - accuracy: 0.5045 - val_loss: 0.2112 - val_accuracy: 0.4999
# Epoch 47/200
# current running rate: 0.0008940442575003573
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2101 - accuracy: 0.5021 - val_loss: 0.2400 - val_accuracy: 0.4999
# Epoch 48/200
# current running rate: 0.0008878078007619501
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0907 - accuracy: 0.5068 - val_loss: 0.0075 - val_accuracy: 0.5078
# Epoch 49/200
# current running rate: 0.000881614846783416
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0074 - accuracy: 0.5098 - val_loss: 0.0068 - val_accuracy: 0.5078
# Epoch 50/200
# current running rate: 0.0008754650921087711
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0066 - accuracy: 0.5096 - val_loss: 0.0063 - val_accuracy: 0.5078
# Epoch 51/200
# current running rate: 0.0008693582353988059
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0064 - accuracy: 0.5104 - val_loss: 0.0062 - val_accuracy: 0.5078
# Epoch 52/200
# current running rate: 0.0008632939774163194
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0062 - accuracy: 0.5100 - val_loss: 0.0063 - val_accuracy: 0.5078
# Epoch 53/200
# current running rate: 0.0008572720210114575
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0065 - accuracy: 0.5103 - val_loss: 0.0224 - val_accuracy: 0.5075
# Epoch 54/200
# current running rate: 0.0008512920711071511
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0093 - accuracy: 0.5100 - val_loss: 0.0060 - val_accuracy: 0.5078
# Epoch 55/200
# current running rate: 0.0008453538346846588
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0060 - accuracy: 0.5096 - val_loss: 0.0060 - val_accuracy: 0.5078
# Epoch 56/200
# current running rate: 0.0008394570207692074
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0060 - accuracy: 0.5103 - val_loss: 0.0059 - val_accuracy: 0.5078
# Epoch 57/200
# current running rate: 0.0008336013404157353
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0060 - accuracy: 0.5095 - val_loss: 0.0059 - val_accuracy: 0.5078
# Epoch 58/200
# current running rate: 0.0008277865066947336
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0058 - accuracy: 0.5101 - val_loss: 0.0057 - val_accuracy: 0.5078
# Epoch 59/200
# current running rate: 0.0008220122346781865
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0152 - accuracy: 0.5103 - val_loss: 0.1172 - val_accuracy: 0.5027
# Epoch 60/200
# current running rate: 0.0008162782414256099
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0297 - accuracy: 0.5098 - val_loss: 0.0077 - val_accuracy: 0.5078
# Epoch 61/200
# current running rate: 0.0008105842459701871
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0078 - accuracy: 0.5095 - val_loss: 0.0063 - val_accuracy: 0.5078
# Epoch 62/200
# current running rate: 0.0008049299693050015
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0062 - accuracy: 0.5094 - val_loss: 0.0060 - val_accuracy: 0.5078
# Epoch 63/200
# current running rate: 0.0007993151343693651
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0058 - accuracy: 0.5103 - val_loss: 0.0058 - val_accuracy: 0.5078
# Epoch 64/200
# current running rate: 0.0007937394660352427
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0057 - accuracy: 0.5103 - val_loss: 0.0056 - val_accuracy: 0.5078
# Epoch 65/200
# current running rate: 0.0007882026910937704
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0056 - accuracy: 0.5095 - val_loss: 0.0056 - val_accuracy: 0.5078
# Epoch 66/200
# current running rate: 0.0007827045382418681
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0598 - accuracy: 0.4890 - val_loss: 0.1617 - val_accuracy: 0.5019
# Epoch 67/200
# current running rate: 0.0007772447380689461
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0482 - accuracy: 0.5090 - val_loss: 0.0071 - val_accuracy: 0.5078
# Epoch 68/200
# current running rate: 0.0007718230230437035
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0067 - accuracy: 0.5106 - val_loss: 0.0060 - val_accuracy: 0.5078
# Epoch 69/200
# current running rate: 0.0007664391275010192
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0059 - accuracy: 0.5098 - val_loss: 0.0057 - val_accuracy: 0.5079
# Epoch 70/200
# current running rate: 0.0007610927876289343
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0058 - accuracy: 0.5101 - val_loss: 0.0057 - val_accuracy: 0.5078
# Epoch 71/200
# current running rate: 0.0007557837414557255
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0056 - accuracy: 0.5104 - val_loss: 0.0055 - val_accuracy: 0.5078
# Epoch 72/200
# current running rate: 0.000750511728837068
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0055 - accuracy: 0.5092 - val_loss: 0.0056 - val_accuracy: 0.5079
# Epoch 73/200
# current running rate: 0.0007452764914432886
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0152 - accuracy: 0.5091 - val_loss: 0.2101 - val_accuracy: 0.4999
# Epoch 74/200
# current running rate: 0.0007400777727467077
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2939 - accuracy: 0.4200 - val_loss: 0.2098 - val_accuracy: 0.4999
# Epoch 75/200
# current running rate: 0.0007349153180090688
# 938/938 [==============================] - 57s 61ms/step - loss: 0.2221 - accuracy: 0.4993 - val_loss: 0.2193 - val_accuracy: 0.4999
# Epoch 76/200
# current running rate: 0.0007297888742690569
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2167 - accuracy: 0.5017 - val_loss: 0.2083 - val_accuracy: 0.4999
# Epoch 77/200
# current running rate: 0.000724698190329903
# 938/938 [==============================] - 58s 62ms/step - loss: 0.2194 - accuracy: 0.5023 - val_loss: 0.5175 - val_accuracy: 0.0559
# Epoch 78/200
# current running rate: 0.0007196430167470755
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0461 - accuracy: 0.5022 - val_loss: 0.0064 - val_accuracy: 0.5078
# Epoch 79/200
# current running rate: 0.0007146231058160573
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0062 - accuracy: 0.5098 - val_loss: 0.0058 - val_accuracy: 0.5078
# Epoch 80/200
# current running rate: 0.0007096382115602087
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0058 - accuracy: 0.5096 - val_loss: 0.0056 - val_accuracy: 0.5078
# Epoch 81/200
# current running rate: 0.0007046880897187134
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0059 - accuracy: 0.5093 - val_loss: 0.0056 - val_accuracy: 0.5079
# Epoch 00081: early stopping

# %%
# Plot history: MSE
plt.plot(history.history['loss'], label='MSE (training data)')
plt.plot(history.history['val_loss'], label='VAL MSE (validation data)')
plt.title('MSE for Autoencoder')
plt.ylabel('MSE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
# Plot history: ACC
plt.plot(history.history['accuracy'], label='ACC (training data)')
plt.plot(history.history['val_accuracy'], label='VAL ACC (validation data)')
plt.title('acc for Autoencoder')
plt.ylabel('acc value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()

# %%
autoencoder.save('/content/MyDrive/MyDrive/Colab Notebooks/Unsupervised Image Search/models/autoencoder.h5')

# %% [markdown]
# ##3 Get the encoder

# %%
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('encoder').output)
encoder.save('/content/MyDrive/MyDrive/Colab Notebooks/Unsupervised Image Search/models/encoder.h5')

# %% [markdown]
# ##4 Image Search using KNN

# %%
# display the image
query = X_test_normalized[888]
plt.figure(figsize = (5,5))
plt.imshow(query.reshape(28, 28), cmap=plt.cm.copper)

# %%
# remove query image from search
print('initial shape:', X_test_normalized.shape)
X_test_target = np.delete(X_test_normalized, 888, axis=0)
print('current shape:', X_test_target.shape)
# Out:
# initial shape: (10000, 28, 28, 1)
# current shape: (9999, 28, 28, 1)

# %%
# encoder the target images
codes = encoder.predict(X_test_target)
query_code = encoder.predict(query.reshape(1,28,28,1))

print('codes.shape:', codes.shape)
print('query_code.shape:', query_code.shape)
# Out:
# codes.shape: (9999, 7, 7, 256)
# query_code.shape: (1, 7, 7, 256)

# %%
n_neighbors = 5
codes = codes.reshape(-1, 7*7*256)
query_code = query_code.reshape(1, 7*7*256)

# %%
# fit KNN
nearestNeighbors= NearestNeighbors(n_neighbors=n_neighbors).fit(codes)

# %%
distances, indices = nearestNeighbors.kneighbors(np.array(query_code))
closest_images = X_test_target[indices]
closest_images = closest_images.reshape(-1,28,28,1)

# %% [markdown]
# display the result

# %%
query = X_test_normalized[888]
plt.figure(figsize = (5,5))
plt.imshow(query.reshape(28, 28), cmap=plt.cm.copper)

# %%
plt.figure(figsize=(20, 6))
for i in range(n_neigh):
    # display original
    ax = plt.subplot(1, n_neighbors, i+1)
    plt.imshow(closest_images[i].reshape(28, 28), cmap=plt.cm.copper)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()
